# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()
# Out:
# 'C:\\Users\\Janani B\\OneDrive\\Desktop\\weekly task'

# %%
import pandas as pd
dataframe = pd.read_csv(r"C:\Users\Janani B\OneDrive\Desktop\weekly task\zomato-data-.csv")
#give your file path
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet
